# %%
rain = "No"
if rain == "Yes":
    print("Take an umbrella.")
else:
    print("No umbrella needed.")
# Out:
# No umbrella needed.

# %%
# ==
# >=, <=,!=, ==, !=, > , <, and, or, not

# %%
marks = 85
attndance = 70
if marks >= 80 and attndance >= 75:
    print("You are eligible for the exam.")
else:
    print("You are not eligible for the exam.")
# Out:
# You are not eligible for the exam.

# %%
# if, elif,else
if marks >= 80 and attndance >= 75:
    print("You are eligible for the exam.")
elif marks >= 80 and attndance < 75:
    print("You need to improve your attendance.")
else:
    print("You are not eligible for the exam.")
# Out:
# You need to improve your attendance.

# %% [markdown]
# # 🎱 Magic 8-Ball - Python Project Lesson
#
# Welcome to the **Magic 8-Ball Project**! In this lesson, we'll build a fun Python program that gives different "Yes" or "No" answers to any question you ask. You'll learn how to use variables, conditionals, and the random module.
#
# Let's get started step-by-step! 🚀

# %% [markdown]
# ## 🎲 Step 1: Generate a Random Number
# - Import the `random` module.
# - Generate a random number between 1 and 9 using `random.randint(1, 9)`.
# - Print the random number to see it change each time.
#
# 👉 Write your code below:
#
# Hint :
# import random
# random_number = random.randint(1, 9)
# print("Random number:", random_number)  # You can comment this out later

# %%
import random
random_number = random.randint(1, 9)
print("Random number:", random_number)
# Out:
# Random number: 3

# %% [markdown]
# ## 🔄 Step 2: Use Control Flow to Set the Answwer
# Now that we’ve declared all the variables needed, it’s time to implement the core logic of our program!
#
# For this section, we’ll be utilizing control flow using an if/elif/else statement to assign different answers for each randomly generated value.
#
# First, write an if statement where if the random_number is equal to 1, answer is assigned to the phrase “Yes - definitely”
#
# 👉 Fill in the conditions for all 9 possible answers below:

# %% [markdown]
# Next, write an elif statement after the if statement where if the random_number is equal to 2, answer is assigned to the phrase “It is decidedly so”.
#
# Then, continue writing elif statements for each of the remaining phrases for the values 3 to 9.
#
# The 9 possible answers of the Magic 8-Ball are:
#
# "Yes - definitely"
#
# "It is decidedly so"
#
# "Without a doubt"
#
# "Reply hazy, try again"
#
# "Ask again later"
#
# "Better not tell you now"
#
# "My sources say no"
#
# "Outlook not so good"
#
# "Very doubtful"
#
# Hint:
# if random_number == 1:
#     answer = "Yes - definitely"
# elif random_number == 2:
#     answer = "It is decidedly so"
# elif random_number == 3:
#     answer = "Without a doubt"
# elif random_number == 4:
#     answer = "Reply hazy, try again"
# elif random_number == 5:
#     answer = "Ask again later"
# elif random_number == 6:
#     answer = "Better not tell you now"
# elif random_number == 7:
#     answer = "My sources say no"
# elif random_number == 8:
#     answer = "Outlook not so good"
#
# else:
#     answer = "Very doubtful"

# %%
if random_number == 1:
    answer = "Yes - definitely"
elif random_number == 2:
    answer = "It is decidedly so"
elif random_number == 3:
    answer = "Without a doubt"
elif random_number == 4:
    answer = "Reply hazy, try again"
elif random_number == 5:
    answer = "Ask again later"
elif random_number == 6:
    answer = "Better not tell you now"
elif random_number == 7:
    answer = "My sources say no"
elif random_number == 8:
    answer = "Outlook not so good"

else:
    answer = "Very doubtful"

# %% [markdown]
# ## 📢 Step 4: Show the Result
# - Use Input function to ask question
#
# 👉 Try writing this logic now:
#
# Hint:
# user_name = input("What is your name: ")
# print("Hello, "+ user_name +". "+ "ready to ask your question?")
#
# user_question = input("Ask a question: ")
#
# print("Magic 8-Ball's answer:", answer)

# %%
user_name = input("What is your name: ")
print(f"Hello {user_name} ready to ask your question?")

user_question = input("Ask a question: ")

print("Magic 8-Ball's answer:", answer)
# Out:
# Hello Farhan ready to ask your question?
# Magic 8-Ball's answer: Without a doubt

# %% [markdown]
# ## 🎉 Congratulations!
# You've built your own Magic 8-Ball! Try running the notebook multiple times and asking different questions.
#
# ### Optional Challenge:
# - Add more than 9 answers by expanding the random number range.
# - Make the answers even more creative!
#
# Have fun coding! 🚀
